# %%
# !nvidia-smi
# Out:
# Tue Nov  3 08:37:44 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.32.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Import dataset

# %%
# !mkdir data
# !cp drive/My\ Drive/pavement-distress/murad-dataset-rev.zip data/
# !unzip data/murad-dataset-rev.zip > /dev/null
# !rm data/murad-dataset-rev.zip
# !mkdir logs
# !mkdir saved_models

# %% [markdown]
# # Install Dependencies

# %%
# !pip install -U torch==1.5 torchvision==0.6 -f https://download.pytorch.org/whl/cu101/torch_stable.html 
# !pip install cython pyyaml==5.1
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# !gcc --version
# install detectron2:
# !pip install detectron2==0.1.3 -f https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.5/index.html

# %% [markdown]
# # Setup Detectron2

# %%
# You may need to restart your runtime prior to this, to let your installation take effect
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import cv2
import random
from google.colab.patches import cv2_imshow

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog
import torch, torchvision
import copy
import detectron2.data.transforms as T
from detectron2.data import detection_utils as utils
from detectron2.data import DatasetCatalog, MetadataCatalog, build_detection_test_loader, build_detection_train_loader
from detectron2.engine import DefaultTrainer
from detectron2.evaluation import COCOEvaluator
from detectron2.data import DatasetMapper

from detectron2.engine.hooks import HookBase
from detectron2.evaluation import inference_context
from detectron2.utils.logger import log_every_n_seconds
import detectron2.utils.comm as comm
import time
import datetime
from detectron2.config import get_cfg
import os
import logging

# %%
from detectron2.data.datasets import register_coco_instances
register_coco_instances("dataset_train", {}, "/content/train_coco.json", "/content/output_train")
register_coco_instances("dataset_val", {}, "/content/test_coco.json", "/content/output_test")
register_coco_instances("dataset_test", {}, "/content/test_coco.json", "/content/output_test")

# %% [markdown]
# # Create Custom Mapper and Transforms

# %%
def custom_mapper(dataset_dict):
    # Implement a mapper, similar to the default DatasetMapper, but with your own customizations
    dataset_dict = copy.deepcopy(dataset_dict)  # it will be modified by code below
    image = utils.read_image(dataset_dict["file_name"], format="RGB")
    transform_list = [
      T.RandomApply(T.RandomBrightness(0.9, 1.1), prob=0.3),
      T.RandomFlip(prob=0.5, vertical=False, horizontal=True),
      T.RandomFlip(prob=0.2, vertical=True, horizontal=False),
      T.RandomApply(T.RandomContrast(0.9, 1.1), prob=0.3),
      T.RandomApply(T.RandomLighting(0.2), prob=0.3),
      T.RandomApply(T.RandomSaturation(0.9, 1.1), prob=0.3)
    ]
    
    image, transforms = T.apply_transform_gens(transform_list, image)
    dataset_dict["image"] = torch.as_tensor(image.transpose(2, 0, 1).astype("float32"))

    annos = [
        utils.transform_instance_annotations(obj, transforms, image.shape[:2])
        for obj in dataset_dict.pop("annotations")
    ]
    instances = utils.annotations_to_instances(annos, image.shape[:2])
    dataset_dict["instances"] = utils.filter_empty_instances(instances)
    return dataset_dict

# %%
class LossEvalHook(HookBase):
    def __init__(self, eval_period, model, data_loader):
        self._model = model
        self._period = eval_period
        self._data_loader = data_loader
    
    def _do_loss_eval(self):
        # Copying inference_on_dataset from evaluator.py
        total = len(self._data_loader)
        num_warmup = min(5, total - 1)
            
        start_time = time.perf_counter()
        total_compute_time = 0
        losses = []
        for idx, inputs in enumerate(self._data_loader):            
            if idx == num_warmup:
                start_time = time.perf_counter()
                total_compute_time = 0
            start_compute_time = time.perf_counter()
            if torch.cuda.is_available():
                torch.cuda.synchronize()
            total_compute_time += time.perf_counter() - start_compute_time
            iters_after_start = idx + 1 - num_warmup * int(idx >= num_warmup)
            seconds_per_img = total_compute_time / iters_after_start
            if idx >= num_warmup * 2 or seconds_per_img > 5:
                total_seconds_per_img = (time.perf_counter() - start_time) / iters_after_start
                eta = datetime.timedelta(seconds=int(total_seconds_per_img * (total - idx - 1)))
                log_every_n_seconds(
                    logging.INFO,
                    "Loss on Validation  done {}/{}. {:.4f} s / img. ETA={}".format(
                        idx + 1, total, seconds_per_img, str(eta)
                    ),
                    n=5,
                )
            loss_batch = self._get_loss(inputs)
            losses.append(loss_batch)
        mean_loss = np.mean(losses)
        self.trainer.storage.put_scalar('validation_loss', mean_loss)
        comm.synchronize()

        return losses
            
    def _get_loss(self, data):
        # How loss is calculated on train_loop 
        metrics_dict = self._model(data)
        metrics_dict = {
            k: v.detach().cpu().item() if isinstance(v, torch.Tensor) else float(v)
            for k, v in metrics_dict.items()
        }
        total_losses_reduced = sum(loss for loss in metrics_dict.values())
        return total_losses_reduced
        
        
    def after_step(self):
        next_iter = self.trainer.iter + 1
        is_final = next_iter == self.trainer.max_iter
        if is_final or (self._period > 0 and next_iter % self._period == 0):
            self._do_loss_eval()
        self.trainer.storage.put_scalars(timetest=12)

# %% [markdown]
# # Create CocoTrainer Class

# %%
class CocoTrainer(DefaultTrainer):
  @classmethod
  def build_evaluator(cls, cfg, dataset_name, output_folder=None):
    # if output_folder is None:
    #     os.makedirs("coco_eval", exist_ok=True)
    output_folder = "/content/drive/My Drive/pavement-distress/training_logs/retinanet_01/"
    # output_folder = "output"
    return COCOEvaluator(dataset_name, cfg, True, output_folder)
                     
  def build_hooks(self):
      hooks = super().build_hooks()
      hooks.insert(-1,LossEvalHook(
          cfg.TEST.EVAL_PERIOD,
          self.model,
          build_detection_test_loader(
              self.cfg,
              self.cfg.DATASETS.TEST[0],
              DatasetMapper(self.cfg,True)
          )
      ))
      return hooks

  @classmethod
  def build_train_loader(cls, cfg):
    return build_detection_train_loader(cfg, mapper=custom_mapper)

# %% [markdown]
# # Add Hyperparameters

# %%
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/retinanet_R_50_FPN_1x.yaml"))
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/retinanet_R_50_FPN_1x.yaml") 

cfg.DATASETS.TRAIN = ("dataset_train",)
cfg.DATASETS.TEST = ("dataset_val",)

# -----------------------------------------------------------------------------
# INPUT
# -----------------------------------------------------------------------------
cfg.INPUT.MIN_SIZE_TRAIN = (640,)
cfg.INPUT.MAX_SIZE_TRAIN = 768
cfg.INPUT.MIN_SIZE_TEST = 0
cfg.INPUT.MAX_SIZE_TEST = 0

# -----------------------------------------------------------------------------
# DataLoader
# -----------------------------------------------------------------------------
cfg.DATALOADER.NUM_WORKERS = 4

# -----------------------------------------------------------------------------
# SOLVER
# -----------------------------------------------------------------------------
cfg.SOLVER.IMS_PER_BATCH = 16
cfg.BASE_LR = 0.02

cfg.SOLVER.LR_SCHEDULER_NAME = "WarmupCosineLR"
cfg.SOLVER.CHECKPOINT_PERIOD = 2800

cfg.SOLVER.STEPS = (22000, 26000)
cfg.SOLVER.MAX_ITER = 28000
cfg.SOLVER.WEIGHT_DECAY = 4e-5

cfg.SOLVER.CLIP_GRADIENTS.ENABLED = True
cfg.SOLVER.CLIP_GRADIENTS.CLIP_TYPE = 'norm'
cfg.SOLVER.CLIP_GRADIENTS.CLIP_VALUE = 10.0

# -----------------------------------------------------------------------------
# MODEL
# -----------------------------------------------------------------------------
 # Let training initialize from model zoo
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 256
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 17
cfg.OUTPUT_DIR = "/content/drive/My Drive/pavement-distress/training_logs/retinanet_01/"
# cfg.OUTPUT_DIR = 'output'
cfg.MODEL.RETINANET.NUM_CLASSES = 17

# -----------------------------------------------------------------------------
# TEST
# -----------------------------------------------------------------------------
cfg.TEST.EVAL_PERIOD = 2800
# Out:
# Loading config /usr/local/lib/python3.6/dist-packages/detectron2/model_zoo/configs/COCO-Detection/../Base-RetinaNet.yaml with yaml.unsafe_load. Your machine may be at risk if the file contains malicious content.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Train the model

# %%
# os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = CocoTrainer(cfg)
trainer.resume_or_load(resume=True)
trainer.train()
# Out:
# [11/03 08:43:43 d2.engine.defaults]: Model:
# RetinaNet(
#   (backbone): FPN(
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelP6P7(
#       (p6): Conv2d(2048, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (p7): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     )
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (head): RetinaNetHead(
#     (cls_subnet): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU()
#       (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (5): ReLU()
#       (6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU()
#     )
#     (bbox_subnet): Sequential(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ReLU()
#       (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (5): ReLU()
#       (6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU()
#     )
#     (cls_score): Conv2d(256, 153, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (bbox_pred): Conv2d(256, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (anchor_generator): DefaultAnchorGenerator(
#     (cell_anchors): BufferList()
#   )
# )
# [11/03 08:43:43 d2.data.datasets.coco]: Loaded 1128 images in COCO format from /content/train_coco.json
# [11/03 08:43:43 d2.data.build]: Removed 0 images with no usable annotations. 1128 images left.
# [11/03 08:43:43 d2.data.build]: Distribution of instances among all 17 categories:
# |   category    | #instances   |   category    | #instances   |   category    | #instances   |
# |:-------------:|:-------------|:-------------:|:-------------|:-------------:|:-------------|
# | Alligator_C.. | 261          | Block_Crack.. | 442          | Bumps_Sags_FP | 5            |
# | Corner_Brea.. | 119          | Divided_Sla.. | 43           | Edge_Crack_FP | 180          |
# |   Joint_RP    | 356          | Linear_Crac.. | 32           | Longitudina.. | 260          |
# | Manhole_Cover | 95           | Miscellanio.. | 403          | Patch_Utili.. | 273          |
# |  Pothole_FP   | 134          |  Rutting_FP   | 2            | Slippage_Cr.. | 27           |
# | Transverse_.. | 229          | Weather_Rav.. | 89           |               |              |
# |     total     | 2950         |               |              |               |              |
# [11/03 08:43:43 d2.data.common]: Serializing 1128 elements to byte tensors and concatenating them all ...
# [11/03 08:43:43 d2.data.common]: Serialized dataset takes 0.31 MiB
# [11/03 08:43:43 d2.data.build]: Using training sampler TrainingSampler
# [11/03 08:43:45 d2.data.detection_utils]: TransformGens used in training: [ResizeShortestEdge(short_edge_length=(640,), max_size=768, sample_style='choice'), RandomFlip()]
# [11/03 08:43:45 d2.data.datasets.coco]: Loaded 180 images in COCO format from /content/test_coco.json
# [11/03 08:43:45 d2.data.build]: Distribution of instances among all 17 categories:
# |   category    | #instances   |   category    | #instances   |   category    | #instances   |
# |:-------------:|:-------------|:-------------:|:-------------|:-------------:|:-------------|
# | Alligator_C.. | 35           | Block_Crack.. | 81           | Bumps_Sags_FP | 4            |
# | Corner_Brea.. | 5            | Divided_Sla.. | 2            | Edge_Crack_FP | 4            |
# |   Joint_RP    | 114          | Linear_Crac.. | 3            | Longitudina.. | 20           |
# | Manhole_Cover | 4            | Miscellanio.. | 33           | Patch_Utili.. | 4            |
# |  Pothole_FP   | 10           |  Rutting_FP   | 1            | Slippage_Cr.. | 2            |
# | Transverse_.. | 23           | Weather_Rav.. | 2            |               |              |
# |     total     | 347          |               |              |               |              |
# [11/03 08:43:45 d2.data.common]: Serializing 180 elements to byte tensors and concatenating them all ...
# [11/03 08:43:45 d2.data.common]: Serialized dataset takes 0.04 MiB
# [11/03 08:43:46 d2.engine.train_loop]: Starting training from iteration 16800
# [11/03 08:44:31 d2.utils.events]:  eta: 6:46:14  iter: 16819  total_loss: 0.003  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.1943  data_time: 0.4856  lr: 0.003445  max_mem: 8089M
# [11/03 08:45:17 d2.utils.events]:  eta: 6:55:50  iter: 16839  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2416  data_time: 0.4698  lr: 0.003434  max_mem: 8089M
# [11/03 08:46:01 d2.utils.events]:  eta: 6:50:21  iter: 16859  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2230  data_time: 0.4000  lr: 0.003423  max_mem: 8089M
# [11/03 08:46:46 d2.utils.events]:  eta: 6:52:06  iter: 16879  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2273  data_time: 0.4365  lr: 0.003413  max_mem: 8089M
# [11/03 08:47:31 d2.utils.events]:  eta: 6:52:23  iter: 16899  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2308  data_time: 0.4519  lr: 0.003402  max_mem: 8089M
# [11/03 08:48:15 d2.utils.events]:  eta: 6:52:42  iter: 16919  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2325  data_time: 0.4394  lr: 0.003392  max_mem: 8089M
# [11/03 08:49:00 d2.utils.events]:  eta: 6:51:57  iter: 16939  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2335  data_time: 0.4402  lr: 0.003381  max_mem: 8089M
# [11/03 08:49:45 d2.utils.events]:  eta: 6:51:38  iter: 16959  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2360  data_time: 0.4524  lr: 0.003370  max_mem: 8089M
# [11/03 08:50:30 d2.utils.events]:  eta: 6:50:47  iter: 16979  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2342  data_time: 0.4292  lr: 0.003360  max_mem: 8089M
# [11/03 08:51:14 d2.utils.events]:  eta: 6:48:11  iter: 16999  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2302  data_time: 0.3938  lr: 0.003349  max_mem: 8089M
# [11/03 08:51:58 d2.utils.events]:  eta: 6:47:17  iter: 17019  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2291  data_time: 0.4168  lr: 0.003339  max_mem: 8089M
# [11/03 08:52:42 d2.utils.events]:  eta: 6:46:32  iter: 17039  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2278  data_time: 0.4137  lr: 0.003328  max_mem: 8089M
# [11/03 08:53:26 d2.utils.events]:  eta: 6:45:47  iter: 17059  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2262  data_time: 0.4145  lr: 0.003317  max_mem: 8089M
# [11/03 08:54:11 d2.utils.events]:  eta: 6:45:25  iter: 17079  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2270  data_time: 0.4453  lr: 0.003307  max_mem: 8089M
# [11/03 08:54:55 d2.utils.events]:  eta: 6:44:29  iter: 17099  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2262  data_time: 0.4204  lr: 0.003296  max_mem: 8089M
# [11/03 08:55:40 d2.utils.events]:  eta: 6:43:44  iter: 17119  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2250  data_time: 0.4137  lr: 0.003286  max_mem: 8089M
# [11/03 08:56:25 d2.utils.events]:  eta: 6:43:00  iter: 17139  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2261  data_time: 0.4509  lr: 0.003275  max_mem: 8089M
# [11/03 08:57:09 d2.utils.events]:  eta: 6:42:13  iter: 17159  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2255  data_time: 0.4213  lr: 0.003265  max_mem: 8089M
# [11/03 08:57:53 d2.utils.events]:  eta: 6:41:20  iter: 17179  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2255  data_time: 0.4353  lr: 0.003254  max_mem: 8089M
# [11/03 08:58:38 d2.utils.events]:  eta: 6:40:33  iter: 17199  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2245  data_time: 0.4127  lr: 0.003244  max_mem: 8089M
# [11/03 08:59:22 d2.utils.events]:  eta: 6:39:51  iter: 17219  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2247  data_time: 0.4382  lr: 0.003233  max_mem: 8089M
# [11/03 09:00:07 d2.utils.events]:  eta: 6:39:07  iter: 17239  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2260  data_time: 0.4540  lr: 0.003223  max_mem: 8089M
# [11/03 09:00:52 d2.utils.events]:  eta: 6:38:19  iter: 17259  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2260  data_time: 0.4232  lr: 0.003212  max_mem: 8089M
# [11/03 09:01:36 d2.utils.events]:  eta: 6:37:08  iter: 17279  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2254  data_time: 0.4143  lr: 0.003202  max_mem: 8089M
# [11/03 09:02:21 d2.utils.events]:  eta: 6:36:46  iter: 17299  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2264  data_time: 0.4656  lr: 0.003191  max_mem: 8089M
# [11/03 09:03:05 d2.utils.events]:  eta: 6:35:39  iter: 17319  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2254  data_time: 0.4078  lr: 0.003181  max_mem: 8089M
# [11/03 09:03:49 d2.utils.events]:  eta: 6:34:54  iter: 17339  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2254  data_time: 0.4373  lr: 0.003170  max_mem: 8089M
# [11/03 09:04:34 d2.utils.events]:  eta: 6:34:11  iter: 17359  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2254  data_time: 0.4238  lr: 0.003160  max_mem: 8089M
# [11/03 09:05:19 d2.utils.events]:  eta: 6:33:41  iter: 17379  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2263  data_time: 0.4471  lr: 0.003149  max_mem: 8089M
# [11/03 09:06:03 d2.utils.events]:  eta: 6:32:42  iter: 17399  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2257  data_time: 0.4118  lr: 0.003139  max_mem: 8089M
# [11/03 09:06:48 d2.utils.events]:  eta: 6:32:12  iter: 17419  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2263  data_time: 0.4441  lr: 0.003129  max_mem: 8089M
# [11/03 09:07:33 d2.utils.events]:  eta: 6:31:19  iter: 17439  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2262  data_time: 0.4288  lr: 0.003118  max_mem: 8089M
# [11/03 09:08:17 d2.utils.events]:  eta: 6:30:34  iter: 17459  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2263  data_time: 0.4345  lr: 0.003108  max_mem: 8089M
# [11/03 09:09:01 d2.utils.events]:  eta: 6:29:33  iter: 17479  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2253  data_time: 0.3873  lr: 0.003097  max_mem: 8089M
# [11/03 09:09:45 d2.utils.events]:  eta: 6:28:39  iter: 17499  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2249  data_time: 0.4208  lr: 0.003087  max_mem: 8089M
# [11/03 09:10:30 d2.utils.events]:  eta: 6:27:52  iter: 17519  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2246  data_time: 0.4152  lr: 0.003077  max_mem: 8089M
# [11/03 09:11:13 d2.utils.events]:  eta: 6:26:56  iter: 17539  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2234  data_time: 0.3855  lr: 0.003066  max_mem: 8089M
# [11/03 09:11:57 d2.utils.events]:  eta: 6:26:02  iter: 17559  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2228  data_time: 0.4000  lr: 0.003056  max_mem: 8089M
# [11/03 09:12:41 d2.utils.events]:  eta: 6:25:14  iter: 17579  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2223  data_time: 0.4100  lr: 0.003046  max_mem: 8089M
# [11/03 09:13:26 d2.utils.events]:  eta: 6:24:32  iter: 17599  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2222  data_time: 0.4286  lr: 0.003035  max_mem: 8089M
# [11/03 09:14:10 d2.utils.events]:  eta: 6:23:49  iter: 17619  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2227  data_time: 0.4465  lr: 0.003025  max_mem: 8089M
# [11/03 09:14:55 d2.utils.events]:  eta: 6:23:04  iter: 17639  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2224  data_time: 0.4161  lr: 0.003015  max_mem: 8089M
# [11/03 09:15:39 d2.utils.events]:  eta: 6:22:21  iter: 17659  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2225  data_time: 0.4376  lr: 0.003004  max_mem: 8089M
# [11/03 09:16:24 d2.utils.events]:  eta: 6:21:41  iter: 17679  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2231  data_time: 0.4494  lr: 0.002994  max_mem: 8089M
# [11/03 09:17:09 d2.utils.events]:  eta: 6:21:01  iter: 17699  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2231  data_time: 0.4341  lr: 0.002984  max_mem: 8089M
# [11/03 09:17:53 d2.utils.events]:  eta: 6:20:18  iter: 17719  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2233  data_time: 0.4337  lr: 0.002974  max_mem: 8089M
# [11/03 09:18:38 d2.utils.events]:  eta: 6:19:34  iter: 17739  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2232  data_time: 0.4152  lr: 0.002963  max_mem: 8089M
# [11/03 09:19:22 d2.utils.events]:  eta: 6:18:56  iter: 17759  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2233  data_time: 0.4356  lr: 0.002953  max_mem: 8089M
# [11/03 09:20:06 d2.utils.events]:  eta: 6:18:01  iter: 17779  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2226  data_time: 0.3877  lr: 0.002943  max_mem: 8089M
# [11/03 09:20:50 d2.utils.events]:  eta: 6:17:11  iter: 17799  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2219  data_time: 0.3973  lr: 0.002933  max_mem: 8089M
# [11/03 09:21:35 d2.utils.events]:  eta: 6:16:41  iter: 17819  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2221  data_time: 0.4426  lr: 0.002923  max_mem: 8089M
# [11/03 09:22:19 d2.utils.events]:  eta: 6:15:44  iter: 17839  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2220  data_time: 0.4290  lr: 0.002912  max_mem: 8089M
# [11/03 09:23:03 d2.utils.events]:  eta: 6:15:00  iter: 17859  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2216  data_time: 0.4127  lr: 0.002902  max_mem: 8089M
# [11/03 09:23:47 d2.utils.events]:  eta: 6:14:04  iter: 17879  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2209  data_time: 0.3875  lr: 0.002892  max_mem: 8089M
# [11/03 09:24:31 d2.utils.events]:  eta: 6:13:15  iter: 17899  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2208  data_time: 0.4204  lr: 0.002882  max_mem: 8089M
# [11/03 09:25:16 d2.utils.events]:  eta: 6:12:31  iter: 17919  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2211  data_time: 0.4552  lr: 0.002872  max_mem: 8089M
# [11/03 09:25:59 d2.utils.events]:  eta: 6:11:26  iter: 17939  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2204  data_time: 0.3907  lr: 0.002861  max_mem: 8089M
# [11/03 09:26:43 d2.utils.events]:  eta: 6:10:28  iter: 17959  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2200  data_time: 0.4068  lr: 0.002851  max_mem: 8089M
# [11/03 09:27:27 d2.utils.events]:  eta: 6:09:44  iter: 17979  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2197  data_time: 0.4156  lr: 0.002841  max_mem: 8089M
# [11/03 09:28:11 d2.utils.events]:  eta: 6:08:56  iter: 17999  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2191  data_time: 0.3866  lr: 0.002831  max_mem: 8089M
# [11/03 09:28:55 d2.utils.events]:  eta: 6:08:19  iter: 18019  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2192  data_time: 0.4278  lr: 0.002821  max_mem: 8089M
# [11/03 09:29:39 d2.utils.events]:  eta: 6:07:18  iter: 18039  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2187  data_time: 0.3921  lr: 0.002811  max_mem: 8089M
# [11/03 09:30:23 d2.utils.events]:  eta: 6:06:39  iter: 18059  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2184  data_time: 0.4074  lr: 0.002801  max_mem: 8089M
# [11/03 09:31:08 d2.utils.events]:  eta: 6:05:44  iter: 18079  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2183  data_time: 0.4188  lr: 0.002791  max_mem: 8089M
# [11/03 09:31:52 d2.utils.events]:  eta: 6:04:59  iter: 18099  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2182  data_time: 0.4173  lr: 0.002781  max_mem: 8089M
# [11/03 09:32:35 d2.utils.events]:  eta: 6:04:07  iter: 18119  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2176  data_time: 0.3830  lr: 0.002771  max_mem: 8089M
# [11/03 09:33:20 d2.utils.events]:  eta: 6:03:23  iter: 18139  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2175  data_time: 0.4246  lr: 0.002761  max_mem: 8089M
# [11/03 09:34:04 d2.utils.events]:  eta: 6:02:43  iter: 18159  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2176  data_time: 0.4360  lr: 0.002751  max_mem: 8089M
# [11/03 09:34:48 d2.utils.events]:  eta: 6:01:57  iter: 18179  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2176  data_time: 0.4285  lr: 0.002741  max_mem: 8089M
# [11/03 09:35:32 d2.utils.events]:  eta: 6:01:00  iter: 18199  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2172  data_time: 0.3989  lr: 0.002731  max_mem: 8089M
# [11/03 09:36:17 d2.utils.events]:  eta: 6:00:16  iter: 18219  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2173  data_time: 0.4317  lr: 0.002721  max_mem: 8089M
# [11/03 09:37:01 d2.utils.events]:  eta: 5:59:28  iter: 18239  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2172  data_time: 0.4259  lr: 0.002711  max_mem: 8089M
# [11/03 09:37:45 d2.utils.events]:  eta: 5:58:38  iter: 18259  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2166  data_time: 0.3790  lr: 0.002701  max_mem: 8089M
# [11/03 09:38:28 d2.utils.events]:  eta: 5:57:53  iter: 18279  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2164  data_time: 0.3978  lr: 0.002691  max_mem: 8089M
# [11/03 09:39:13 d2.utils.events]:  eta: 5:57:12  iter: 18299  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2164  data_time: 0.4248  lr: 0.002681  max_mem: 8089M
# [11/03 09:39:56 d2.utils.events]:  eta: 5:56:31  iter: 18319  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2158  data_time: 0.3822  lr: 0.002671  max_mem: 8089M
# [11/03 09:40:40 d2.utils.events]:  eta: 5:55:49  iter: 18339  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2156  data_time: 0.4127  lr: 0.002661  max_mem: 8089M
# [11/03 09:41:25 d2.utils.events]:  eta: 5:55:00  iter: 18359  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2157  data_time: 0.4153  lr: 0.002651  max_mem: 8089M
# [11/03 09:42:09 d2.utils.events]:  eta: 5:54:02  iter: 18379  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2154  data_time: 0.4088  lr: 0.002641  max_mem: 8089M
# [11/03 09:42:52 d2.utils.events]:  eta: 5:53:14  iter: 18399  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2151  data_time: 0.4005  lr: 0.002631  max_mem: 8089M
# [11/03 09:43:37 d2.utils.events]:  eta: 5:52:29  iter: 18419  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2152  data_time: 0.4274  lr: 0.002621  max_mem: 8089M
# [11/03 09:44:21 d2.utils.events]:  eta: 5:51:43  iter: 18439  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2150  data_time: 0.4029  lr: 0.002611  max_mem: 8089M
# [11/03 09:45:05 d2.utils.events]:  eta: 5:50:50  iter: 18459  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2147  data_time: 0.3942  lr: 0.002602  max_mem: 8089M
# [11/03 09:45:49 d2.utils.events]:  eta: 5:50:14  iter: 18479  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2145  data_time: 0.4037  lr: 0.002592  max_mem: 8089M
# [11/03 09:46:32 d2.utils.events]:  eta: 5:49:18  iter: 18499  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2142  data_time: 0.3932  lr: 0.002582  max_mem: 8089M
# [11/03 09:47:16 d2.utils.events]:  eta: 5:48:32  iter: 18519  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2140  data_time: 0.4048  lr: 0.002572  max_mem: 8089M
# [11/03 09:48:01 d2.utils.events]:  eta: 5:47:51  iter: 18539  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2140  data_time: 0.4148  lr: 0.002562  max_mem: 8089M
# [11/03 09:48:45 d2.utils.events]:  eta: 5:47:20  iter: 18559  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2142  data_time: 0.4485  lr: 0.002552  max_mem: 8089M
# [11/03 09:49:29 d2.utils.events]:  eta: 5:46:30  iter: 18579  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2138  data_time: 0.3874  lr: 0.002543  max_mem: 8089M
# [11/03 09:50:13 d2.utils.events]:  eta: 5:45:38  iter: 18599  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2138  data_time: 0.4099  lr: 0.002533  max_mem: 8089M
# [11/03 09:50:57 d2.utils.events]:  eta: 5:44:44  iter: 18619  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2137  data_time: 0.4096  lr: 0.002523  max_mem: 8089M
# [11/03 09:51:41 d2.utils.events]:  eta: 5:44:01  iter: 18639  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2136  data_time: 0.4097  lr: 0.002513  max_mem: 8089M
# [11/03 09:52:26 d2.utils.events]:  eta: 5:43:13  iter: 18659  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2137  data_time: 0.4372  lr: 0.002504  max_mem: 8089M
# [11/03 09:53:10 d2.utils.events]:  eta: 5:42:22  iter: 18679  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2135  data_time: 0.4007  lr: 0.002494  max_mem: 8089M
# [11/03 09:53:54 d2.utils.events]:  eta: 5:41:35  iter: 18699  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2135  data_time: 0.4211  lr: 0.002484  max_mem: 8089M
# [11/03 09:54:38 d2.utils.events]:  eta: 5:40:40  iter: 18719  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2133  data_time: 0.3986  lr: 0.002475  max_mem: 8089M
# [11/03 09:55:22 d2.utils.events]:  eta: 5:39:54  iter: 18739  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2131  data_time: 0.4008  lr: 0.002465  max_mem: 8089M
# [11/03 09:56:06 d2.utils.events]:  eta: 5:39:09  iter: 18759  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2130  data_time: 0.4123  lr: 0.002455  max_mem: 8089M
# [11/03 09:56:50 d2.utils.events]:  eta: 5:38:29  iter: 18779  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2129  data_time: 0.4066  lr: 0.002446  max_mem: 8089M
# [11/03 09:57:34 d2.utils.events]:  eta: 5:37:45  iter: 18799  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2126  data_time: 0.3920  lr: 0.002436  max_mem: 8089M
# [11/03 09:58:18 d2.utils.events]:  eta: 5:36:55  iter: 18819  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2124  data_time: 0.4087  lr: 0.002426  max_mem: 8089M
# [11/03 09:59:02 d2.utils.events]:  eta: 5:36:08  iter: 18839  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2123  data_time: 0.4137  lr: 0.002417  max_mem: 8089M
# [11/03 09:59:46 d2.utils.events]:  eta: 5:35:23  iter: 18859  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2123  data_time: 0.4103  lr: 0.002407  max_mem: 8089M
# [11/03 10:00:29 d2.utils.events]:  eta: 5:34:38  iter: 18879  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2120  data_time: 0.3933  lr: 0.002398  max_mem: 8089M
# [11/03 10:01:13 d2.utils.events]:  eta: 5:33:51  iter: 18899  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2117  data_time: 0.3851  lr: 0.002388  max_mem: 8089M
# [11/03 10:01:57 d2.utils.events]:  eta: 5:33:04  iter: 18919  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2117  data_time: 0.4167  lr: 0.002378  max_mem: 8089M
# [11/03 10:02:41 d2.utils.events]:  eta: 5:32:25  iter: 18939  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2114  data_time: 0.3913  lr: 0.002369  max_mem: 8089M
# [11/03 10:03:25 d2.utils.events]:  eta: 5:31:42  iter: 18959  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2113  data_time: 0.4013  lr: 0.002359  max_mem: 8089M
# [11/03 10:04:09 d2.utils.events]:  eta: 5:30:58  iter: 18979  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2113  data_time: 0.4180  lr: 0.002350  max_mem: 8089M
# [11/03 10:04:54 d2.utils.events]:  eta: 5:30:17  iter: 18999  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2114  data_time: 0.4247  lr: 0.002340  max_mem: 8089M
# [11/03 10:05:38 d2.utils.events]:  eta: 5:29:31  iter: 19019  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2113  data_time: 0.4121  lr: 0.002331  max_mem: 8089M
# [11/03 10:06:21 d2.utils.events]:  eta: 5:28:46  iter: 19039  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2110  data_time: 0.3883  lr: 0.002321  max_mem: 8089M
# [11/03 10:07:05 d2.utils.events]:  eta: 5:28:02  iter: 19059  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2110  data_time: 0.4254  lr: 0.002312  max_mem: 8089M
# [11/03 10:07:49 d2.utils.events]:  eta: 5:27:16  iter: 19079  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2108  data_time: 0.4031  lr: 0.002302  max_mem: 8089M
# [11/03 10:08:34 d2.utils.events]:  eta: 5:26:33  iter: 19099  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2110  data_time: 0.4303  lr: 0.002293  max_mem: 8089M
# [11/03 10:09:17 d2.utils.events]:  eta: 5:25:49  iter: 19119  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2106  data_time: 0.3752  lr: 0.002284  max_mem: 8089M
# [11/03 10:10:02 d2.utils.events]:  eta: 5:25:03  iter: 19139  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2107  data_time: 0.4325  lr: 0.002274  max_mem: 8089M
# [11/03 10:10:46 d2.utils.events]:  eta: 5:24:10  iter: 19159  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2106  data_time: 0.3983  lr: 0.002265  max_mem: 8089M
# [11/03 10:11:29 d2.utils.events]:  eta: 5:23:18  iter: 19179  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2104  data_time: 0.3936  lr: 0.002255  max_mem: 8089M
# [11/03 10:12:13 d2.utils.events]:  eta: 5:22:31  iter: 19199  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2101  data_time: 0.3781  lr: 0.002246  max_mem: 8089M
# [11/03 10:12:56 d2.utils.events]:  eta: 5:21:36  iter: 19219  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2097  data_time: 0.3816  lr: 0.002237  max_mem: 8089M
# [11/03 10:13:40 d2.utils.events]:  eta: 5:20:39  iter: 19239  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2095  data_time: 0.3900  lr: 0.002227  max_mem: 8089M
# [11/03 10:14:24 d2.utils.events]:  eta: 5:19:55  iter: 19259  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2093  data_time: 0.4017  lr: 0.002218  max_mem: 8089M
# [11/03 10:15:07 d2.utils.events]:  eta: 5:19:03  iter: 19279  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2091  data_time: 0.3854  lr: 0.002209  max_mem: 8089M
# [11/03 10:15:51 d2.utils.events]:  eta: 5:18:17  iter: 19299  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2090  data_time: 0.4040  lr: 0.002199  max_mem: 8089M
# [11/03 10:16:35 d2.utils.events]:  eta: 5:17:52  iter: 19319  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2090  data_time: 0.4097  lr: 0.002190  max_mem: 8089M
# [11/03 10:17:19 d2.utils.events]:  eta: 5:16:49  iter: 19339  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2087  data_time: 0.3773  lr: 0.002181  max_mem: 8089M
# [11/03 10:18:02 d2.utils.events]:  eta: 5:15:52  iter: 19359  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2084  data_time: 0.3892  lr: 0.002172  max_mem: 8089M
# [11/03 10:18:46 d2.utils.events]:  eta: 5:15:08  iter: 19379  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2082  data_time: 0.3823  lr: 0.002162  max_mem: 8089M
# [11/03 10:19:30 d2.utils.events]:  eta: 5:14:35  iter: 19399  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2082  data_time: 0.4303  lr: 0.002153  max_mem: 8089M
# [11/03 10:20:13 d2.utils.events]:  eta: 5:13:39  iter: 19419  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2079  data_time: 0.3766  lr: 0.002144  max_mem: 8089M
# [11/03 10:20:57 d2.utils.events]:  eta: 5:12:54  iter: 19439  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2078  data_time: 0.4176  lr: 0.002135  max_mem: 8089M
# [11/03 10:21:41 d2.utils.events]:  eta: 5:12:09  iter: 19459  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2076  data_time: 0.3938  lr: 0.002125  max_mem: 8089M
# [11/03 10:22:25 d2.utils.events]:  eta: 5:11:23  iter: 19479  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2074  data_time: 0.3854  lr: 0.002116  max_mem: 8089M
# [11/03 10:23:09 d2.utils.events]:  eta: 5:10:41  iter: 19499  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2073  data_time: 0.4063  lr: 0.002107  max_mem: 8089M
# [11/03 10:23:53 d2.utils.events]:  eta: 5:09:57  iter: 19519  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2073  data_time: 0.4272  lr: 0.002098  max_mem: 8089M
# [11/03 10:24:36 d2.utils.events]:  eta: 5:09:04  iter: 19539  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  time: 2.2071  data_time: 0.3884  lr: 0.002089  max_mem: 8089M
# [11/03 10:25:20 d2.utils.events]:  eta: 5:08:09  iter: 19559  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2069  data_time: 0.3878  lr: 0.002080  max_mem: 8089M
# [11/03 10:26:03 d2.utils.events]:  eta: 5:07:20  iter: 19579  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  time: 2.2067  data_time: 0.3929  lr: 0.002071  max_mem: 8089M
# [11/03 10:26:48 d2.data.datasets.coco]: Loaded 180 images in COCO format from /content/test_coco.json
# [11/03 10:26:48 d2.data.common]: Serializing 180 elements to byte tensors and concatenating them all ...
# [11/03 10:26:48 d2.data.common]: Serialized dataset takes 0.04 MiB
# [11/03 10:26:48 d2.evaluation.evaluator]: Start inference on 180 images
# [11/03 10:26:49 d2.evaluation.evaluator]: Inference done 11/180. 0.0637 s / img. ETA=0:00:10
# [11/03 10:26:54 d2.evaluation.evaluator]: Inference done 89/180. 0.0636 s / img. ETA=0:00:05
# [11/03 10:26:59 d2.evaluation.evaluator]: Inference done 166/180. 0.0639 s / img. ETA=0:00:00
# [11/03 10:27:01 d2.evaluation.evaluator]: Total inference time: 0:00:11.508533 (0.065763 s / img per device, on 1 devices)
# [11/03 10:27:01 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:11 (0.063873 s / img per device, on 1 devices)
# [11/03 10:27:01 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [11/03 10:27:01 d2.evaluation.coco_evaluation]: Saving results to /content/drive/My Drive/pavement-distress/training_logs/retinanet_01/coco_instances_results.json
# [11/03 10:27:02 d2.evaluation.coco_evaluation]: Evaluating predictions ...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.25s).
# Accumulating evaluation results...
# DONE (t=0.07s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.161
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.382
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.129
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.187
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.163
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.152
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.216
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.222
# [11/03 10:27:02 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 16.093 | 38.178 | 12.944 | 0.000 | 18.748 | 16.264 |
# [11/03 10:27:02 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category            | AP     | category               | AP     | category              | AP     |
# |:--------------------|:-------|:-----------------------|:-------|:----------------------|:-------|
# | Alligator_Crack_FP  | 5.845  | Block_Crack_FP         | 52.547 | Bumps_Sags_FP         | 0.000  |
# | Corner_Break_RP     | 24.554 | Divided_Slab_Crack_RP  | 5.050  | Edge_Crack_FP         | 3.193  |
# | Joint_RP            | 4.989  | Linear_Crack_RP        | 29.158 | Longitudinal_Crack_FP | 2.376  |
# | Manhole_Cover       | 56.931 | Miscellanious_Crack_FP | 0.305  | Patch_Utility_Cut_FP  | 20.594 |
# | Pothole_FP          | 41.608 | Rutting_FP             | 0.000  | Slippage_Crack_FP     | 6.312  |
# | Transverse_Crack_FP | 2.547  | Weather_Raveling_FP    | 17.574 |                       |        |
# [11/03 10:27:02 d2.engine.defaults]: Evaluation results for dataset_val in csv format:
# [11/03 10:27:02 d2.evaluation.testing]: copypaste: Task: bbox
# [11/03 10:27:02 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [11/03 10:27:02 d2.evaluation.testing]: copypaste: 16.0932,38.1780,12.9437,0.0000,18.7477,16.2642
# [11/03 10:27:03 detectron2]: Loss on Validation  done 11/180. 0.0000 s / img. ETA=0:00:08
# [11/03 10:27:08 detectron2]: Loss on Validation  done 90/180. 0.0000 s / img. ETA=0:00:05
# [11/03 10:27:13 detectron2]: Loss on Validation  done 169/180. 0.0000 s / img. ETA=0:00:00
# [11/03 10:27:14 d2.utils.events]:  eta: 5:06:36  iter: 19599  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.295  time: 2.2066  data_time: 0.4100  lr: 0.002062  max_mem: 8089M
# [11/03 10:27:58 d2.utils.events]:  eta: 5:05:56  iter: 19619  total_loss: 0.003  loss_cls: 0.000  loss_box_reg: 0.002  validation_loss: 2.295  time: 2.2067  data_time: 0.4386  lr: 0.002052  max_mem: 8089M
# [11/03 10:28:42 d2.utils.events]:  eta: 5:05:06  iter: 19639  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.295  time: 2.2066  data_time: 0.4020  lr: 0.002043  max_mem: 8089M
# [11/03 10:29:26 d2.utils.events]:  eta: 5:04:21  iter: 19659  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.295  time: 2.2064  data_time: 0.3939  lr: 0.002034  max_mem: 8089M
# [11/03 10:30:09 d2.utils.events]:  eta: 5:03:30  iter: 19679  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.295  time: 2.2060  data_time: 0.3694  lr: 0.002025  max_mem: 8089M
# [11/03 10:30:52 d2.utils.events]:  eta: 5:02:39  iter: 19699  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.295  time: 2.2057  data_time: 0.3662  lr: 0.002016  max_mem: 8089M
# [11/03 10:31:36 d2.utils.events]:  eta: 5:01:58  iter: 19719  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.295  time: 2.2057  data_time: 0.4128  lr: 0.002007  max_mem: 8089M
# [11/03 10:32:20 d2.utils.events]:  eta: 5:01:14  iter: 19739  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.295  time: 2.2057  data_time: 0.4126  lr: 0.001998  max_mem: 8089M
# [11/03 10:33:04 d2.utils.events]:  eta: 5:00:25  iter: 19759  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.295  time: 2.2054  data_time: 0.3768  lr: 0.001989  max_mem: 8089M
# [11/03 10:33:48 d2.utils.events]:  eta: 4:59:40  iter: 19779  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.295  time: 2.2054  data_time: 0.3971  lr: 0.001980  max_mem: 8089M
# [11/03 10:34:31 d2.utils.events]:  eta: 4:58:54  iter: 19799  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.295  time: 2.2052  data_time: 0.3976  lr: 0.001971  max_mem: 8089M
# [11/03 10:35:15 d2.utils.events]:  eta: 4:58:01  iter: 19819  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.295  time: 2.2049  data_time: 0.3789  lr: 0.001963  max_mem: 8089M
# [11/03 10:35:59 d2.utils.events]:  eta: 4:57:16  iter: 19839  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  validation_loss: 2.295  time: 2.2050  data_time: 0.4137  lr: 0.001954  max_mem: 8089M
# [11/03 10:36:43 d2.utils.events]:  eta: 4:56:32  iter: 19859  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.295  time: 2.2050  data_time: 0.4097  lr: 0.001945  max_mem: 8089M
# [11/03 10:37:26 d2.utils.events]:  eta: 4:55:45  iter: 19879  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.295  time: 2.2048  data_time: 0.3837  lr: 0.001936  max_mem: 8089M
# [11/03 10:38:10 d2.utils.events]:  eta: 4:55:04  iter: 19899  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.295  time: 2.2047  data_time: 0.4049  lr: 0.001927  max_mem: 8089M
# [11/03 10:38:54 d2.utils.events]:  eta: 4:54:21  iter: 19919  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.295  time: 2.2046  data_time: 0.4083  lr: 0.001918  max_mem: 8089M
# ...
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.188
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.157
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.148
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.217
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.217
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.215
# [11/03 12:09:38 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 15.787 | 35.468 | 13.011 | 0.000 | 18.835 | 15.661 |
# [11/03 12:09:38 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category            | AP     | category               | AP     | category              | AP     |
# |:--------------------|:-------|:-----------------------|:-------|:----------------------|:-------|
# | Alligator_Crack_FP  | 5.864  | Block_Crack_FP         | 51.771 | Bumps_Sags_FP         | 0.000  |
# | Corner_Break_RP     | 24.554 | Divided_Slab_Crack_RP  | 0.000  | Edge_Crack_FP         | 1.757  |
# | Joint_RP            | 4.991  | Linear_Crack_RP        | 29.158 | Longitudinal_Crack_FP | 2.376  |
# | Manhole_Cover       | 56.931 | Miscellanious_Crack_FP | 0.341  | Patch_Utility_Cut_FP  | 20.594 |
# | Pothole_FP          | 41.520 | Rutting_FP             | 0.000  | Slippage_Crack_FP     | 8.416  |
# | Transverse_Crack_FP | 2.525  | Weather_Raveling_FP    | 17.574 |                       |        |
# [11/03 12:09:38 d2.engine.defaults]: Evaluation results for dataset_val in csv format:
# [11/03 12:09:38 d2.evaluation.testing]: copypaste: Task: bbox
# [11/03 12:09:38 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [11/03 12:09:38 d2.evaluation.testing]: copypaste: 15.7866,35.4677,13.0113,0.0000,18.8346,15.6606
# [11/03 12:09:40 detectron2]: Loss on Validation  done 11/180. 0.0000 s / img. ETA=0:00:08
# [11/03 12:09:45 detectron2]: Loss on Validation  done 90/180. 0.0000 s / img. ETA=0:00:05
# [11/03 12:09:50 detectron2]: Loss on Validation  done 169/180. 0.0000 s / img. ETA=0:00:00
# [11/03 12:09:51 d2.utils.events]:  eta: 3:23:45  iter: 22399  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1979  data_time: 0.4040  lr: 0.000955  max_mem: 8089M
# [11/03 12:10:34 d2.utils.events]:  eta: 3:22:52  iter: 22419  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  validation_loss: 2.314  time: 2.1978  data_time: 0.3854  lr: 0.000949  max_mem: 8089M
# [11/03 12:11:17 d2.utils.events]:  eta: 3:22:02  iter: 22439  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1977  data_time: 0.3749  lr: 0.000942  max_mem: 8089M
# [11/03 12:12:01 d2.utils.events]:  eta: 3:21:16  iter: 22459  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1976  data_time: 0.3645  lr: 0.000936  max_mem: 8089M
# [11/03 12:12:45 d2.utils.events]:  eta: 3:20:33  iter: 22479  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1976  data_time: 0.4256  lr: 0.000929  max_mem: 8089M
# [11/03 12:13:29 d2.utils.events]:  eta: 3:19:53  iter: 22499  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1976  data_time: 0.4194  lr: 0.000923  max_mem: 8089M
# [11/03 12:14:13 d2.utils.events]:  eta: 3:19:12  iter: 22519  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1977  data_time: 0.4262  lr: 0.000916  max_mem: 8089M
# [11/03 12:14:57 d2.utils.events]:  eta: 3:18:26  iter: 22539  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1977  data_time: 0.4125  lr: 0.000910  max_mem: 8089M
# [11/03 12:15:41 d2.utils.events]:  eta: 3:17:46  iter: 22559  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1977  data_time: 0.3847  lr: 0.000903  max_mem: 8089M
# [11/03 12:16:25 d2.utils.events]:  eta: 3:17:08  iter: 22579  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  validation_loss: 2.314  time: 2.1977  data_time: 0.4110  lr: 0.000897  max_mem: 8089M
# [11/03 12:17:09 d2.utils.events]:  eta: 3:16:24  iter: 22599  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1977  data_time: 0.4022  lr: 0.000890  max_mem: 8089M
# [11/03 12:17:53 d2.utils.events]:  eta: 3:15:40  iter: 22619  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1977  data_time: 0.4121  lr: 0.000884  max_mem: 8089M
# [11/03 12:18:37 d2.utils.events]:  eta: 3:14:57  iter: 22639  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1977  data_time: 0.3909  lr: 0.000878  max_mem: 8089M
# [11/03 12:19:21 d2.utils.events]:  eta: 3:14:13  iter: 22659  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  validation_loss: 2.314  time: 2.1976  data_time: 0.4006  lr: 0.000871  max_mem: 8089M
# [11/03 12:20:04 d2.utils.events]:  eta: 3:13:30  iter: 22679  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1976  data_time: 0.3918  lr: 0.000865  max_mem: 8089M
# [11/03 12:20:48 d2.utils.events]:  eta: 3:12:46  iter: 22699  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1975  data_time: 0.3913  lr: 0.000859  max_mem: 8089M
# [11/03 12:21:32 d2.utils.events]:  eta: 3:12:02  iter: 22719  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  validation_loss: 2.314  time: 2.1975  data_time: 0.4123  lr: 0.000852  max_mem: 8089M
# [11/03 12:22:15 d2.utils.events]:  eta: 3:11:19  iter: 22739  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1975  data_time: 0.3810  lr: 0.000846  max_mem: 8089M
# [11/03 12:22:59 d2.utils.events]:  eta: 3:10:36  iter: 22759  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1975  data_time: 0.4082  lr: 0.000840  max_mem: 8089M
# [11/03 12:23:43 d2.utils.events]:  eta: 3:09:53  iter: 22779  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1975  data_time: 0.3998  lr: 0.000834  max_mem: 8089M
# [11/03 12:24:27 d2.utils.events]:  eta: 3:09:06  iter: 22799  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1974  data_time: 0.4026  lr: 0.000827  max_mem: 8089M
# [11/03 12:25:11 d2.utils.events]:  eta: 3:08:25  iter: 22819  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1974  data_time: 0.4164  lr: 0.000821  max_mem: 8089M
# [11/03 12:25:54 d2.utils.events]:  eta: 3:07:42  iter: 22839  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1973  data_time: 0.3580  lr: 0.000815  max_mem: 8089M
# [11/03 12:26:38 d2.utils.events]:  eta: 3:06:58  iter: 22859  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1972  data_time: 0.3909  lr: 0.000809  max_mem: 8089M
# [11/03 12:27:21 d2.utils.events]:  eta: 3:06:13  iter: 22879  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1972  data_time: 0.3890  lr: 0.000803  max_mem: 8089M
# [11/03 12:28:05 d2.utils.events]:  eta: 3:05:26  iter: 22899  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1972  data_time: 0.4116  lr: 0.000797  max_mem: 8089M
# [11/03 12:28:49 d2.utils.events]:  eta: 3:04:46  iter: 22919  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1972  data_time: 0.4069  lr: 0.000791  max_mem: 8089M
# [11/03 12:29:32 d2.utils.events]:  eta: 3:04:02  iter: 22939  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1970  data_time: 0.3743  lr: 0.000785  max_mem: 8089M
# [11/03 12:30:16 d2.utils.events]:  eta: 3:03:18  iter: 22959  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1970  data_time: 0.3926  lr: 0.000779  max_mem: 8089M
# [11/03 12:31:00 d2.utils.events]:  eta: 3:02:34  iter: 22979  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1969  data_time: 0.3819  lr: 0.000773  max_mem: 8089M
# [11/03 12:31:43 d2.utils.events]:  eta: 3:01:49  iter: 22999  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1969  data_time: 0.3930  lr: 0.000767  max_mem: 8089M
# [11/03 12:32:27 d2.utils.events]:  eta: 3:01:05  iter: 23019  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1968  data_time: 0.3679  lr: 0.000761  max_mem: 8089M
# [11/03 12:33:10 d2.utils.events]:  eta: 3:00:19  iter: 23039  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1967  data_time: 0.3806  lr: 0.000755  max_mem: 8089M
# [11/03 12:33:54 d2.utils.events]:  eta: 2:59:37  iter: 23059  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1967  data_time: 0.4080  lr: 0.000749  max_mem: 8089M
# [11/03 12:34:38 d2.utils.events]:  eta: 2:58:57  iter: 23079  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1967  data_time: 0.4028  lr: 0.000743  max_mem: 8089M
# [11/03 12:35:22 d2.utils.events]:  eta: 2:58:16  iter: 23099  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1967  data_time: 0.3991  lr: 0.000737  max_mem: 8089M
# [11/03 12:36:06 d2.utils.events]:  eta: 2:57:33  iter: 23119  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1967  data_time: 0.4053  lr: 0.000731  max_mem: 8089M
# [11/03 12:36:50 d2.utils.events]:  eta: 2:56:52  iter: 23139  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1968  data_time: 0.4348  lr: 0.000725  max_mem: 8089M
# [11/03 12:37:34 d2.utils.events]:  eta: 2:56:09  iter: 23159  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1967  data_time: 0.3740  lr: 0.000720  max_mem: 8089M
# [11/03 12:38:17 d2.utils.events]:  eta: 2:55:24  iter: 23179  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1967  data_time: 0.3962  lr: 0.000714  max_mem: 8089M
# [11/03 12:39:01 d2.utils.events]:  eta: 2:54:43  iter: 23199  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1967  data_time: 0.4092  lr: 0.000708  max_mem: 8089M
# [11/03 12:39:45 d2.utils.events]:  eta: 2:54:03  iter: 23219  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1967  data_time: 0.4094  lr: 0.000702  max_mem: 8089M
# [11/03 12:40:29 d2.utils.events]:  eta: 2:53:24  iter: 23239  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1966  data_time: 0.3928  lr: 0.000697  max_mem: 8089M
# [11/03 12:41:13 d2.utils.events]:  eta: 2:52:40  iter: 23259  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1966  data_time: 0.3988  lr: 0.000691  max_mem: 8089M
# [11/03 12:41:56 d2.utils.events]:  eta: 2:51:53  iter: 23279  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1965  data_time: 0.3601  lr: 0.000685  max_mem: 8089M
# [11/03 12:42:40 d2.utils.events]:  eta: 2:51:07  iter: 23299  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1965  data_time: 0.4040  lr: 0.000680  max_mem: 8089M
# [11/03 12:43:24 d2.utils.events]:  eta: 2:50:23  iter: 23319  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1965  data_time: 0.3960  lr: 0.000674  max_mem: 8089M
# [11/03 12:44:08 d2.utils.events]:  eta: 2:49:39  iter: 23339  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1965  data_time: 0.4120  lr: 0.000668  max_mem: 8089M
# [11/03 12:44:52 d2.utils.events]:  eta: 2:48:52  iter: 23359  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1965  data_time: 0.3930  lr: 0.000663  max_mem: 8089M
# [11/03 12:45:35 d2.utils.events]:  eta: 2:48:08  iter: 23379  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1964  data_time: 0.3742  lr: 0.000657  max_mem: 8089M
# [11/03 12:46:19 d2.utils.events]:  eta: 2:47:22  iter: 23399  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1964  data_time: 0.4153  lr: 0.000652  max_mem: 8089M
# [11/03 12:47:03 d2.utils.events]:  eta: 2:46:39  iter: 23419  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1963  data_time: 0.3784  lr: 0.000646  max_mem: 8089M
# [11/03 12:47:47 d2.utils.events]:  eta: 2:46:01  iter: 23439  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  validation_loss: 2.314  time: 2.1964  data_time: 0.4343  lr: 0.000641  max_mem: 8089M
# [11/03 12:48:31 d2.utils.events]:  eta: 2:45:20  iter: 23459  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1964  data_time: 0.3965  lr: 0.000635  max_mem: 8089M
# [11/03 12:49:15 d2.utils.events]:  eta: 2:44:36  iter: 23479  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1964  data_time: 0.4111  lr: 0.000630  max_mem: 8089M
# [11/03 12:49:59 d2.utils.events]:  eta: 2:43:51  iter: 23499  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.002  validation_loss: 2.314  time: 2.1964  data_time: 0.4057  lr: 0.000624  max_mem: 8089M
# [11/03 12:50:42 d2.utils.events]:  eta: 2:43:06  iter: 23519  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1963  data_time: 0.3906  lr: 0.000619  max_mem: 8089M
# [11/03 12:51:26 d2.utils.events]:  eta: 2:42:22  iter: 23539  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1964  data_time: 0.4162  lr: 0.000613  max_mem: 8089M
# [11/03 12:52:11 d2.utils.events]:  eta: 2:41:41  iter: 23559  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1964  data_time: 0.4210  lr: 0.000608  max_mem: 8089M
# [11/03 12:52:54 d2.utils.events]:  eta: 2:40:52  iter: 23579  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1963  data_time: 0.3843  lr: 0.000603  max_mem: 8089M
# [11/03 12:53:37 d2.utils.events]:  eta: 2:40:06  iter: 23599  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1962  data_time: 0.3688  lr: 0.000597  max_mem: 8089M
# [11/03 12:54:21 d2.utils.events]:  eta: 2:39:23  iter: 23619  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1962  data_time: 0.4068  lr: 0.000592  max_mem: 8089M
# [11/03 12:55:04 d2.utils.events]:  eta: 2:38:38  iter: 23639  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1961  data_time: 0.3733  lr: 0.000587  max_mem: 8089M
# [11/03 12:55:49 d2.utils.events]:  eta: 2:37:56  iter: 23659  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1962  data_time: 0.4278  lr: 0.000581  max_mem: 8089M
# [11/03 12:56:32 d2.utils.events]:  eta: 2:37:11  iter: 23679  total_loss: 0.001  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1961  data_time: 0.3851  lr: 0.000576  max_mem: 8089M
# [11/03 12:57:16 d2.utils.events]:  eta: 2:36:29  iter: 23699  total_loss: 0.002  loss_cls: 0.000  loss_box_reg: 0.001  validation_loss: 2.314  time: 2.1961  data_time: 0.4066  lr: 0.000571  max_mem: 8089M
